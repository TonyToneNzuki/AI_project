# %%
print('Hello World')
# Out:
# Hello World

# %%
from dotenv import load_dotenv
import os 
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
# Out:
# d:\AI_project\env\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7
)

# %%
llm.invoke("What year are we in and is it a leap year?").content
# Out:
# 'We are in **2024**.\n\nYes, **2024 is a leap year**.'
